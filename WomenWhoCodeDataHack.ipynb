# %%
# import libraries
import boto3, re, sys, math, json, os, sagemaker, urllib.request
from sagemaker import get_execution_role
import numpy as np                                
import pandas as pd                               
import matplotlib.pyplot as plt                   
from IPython.display import Image                 
from IPython.display import display               
from time import gmtime, strftime                 
from sagemaker.predictor import csv_serializer  
import io

# Define IAM role
role = get_execution_role()


prefix = 'sagemaker/DEMO-xgboost-dm'
containers = {'us-west-2': '433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest',
              'us-east-1': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
              'us-east-2': '825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest',
              'eu-west-1': '685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:latest'} # each region has its XGBoost container
my_region = boto3.session.Session().region_name # set the region of the instance
print("Success - the MySageMakerInstance is in the " + my_region + " region. You will use the " + containers[my_region] + " container for your SageMaker endpoint.")
# Out:
# Success - the MySageMakerInstance is in the us-west-2 region. You will use the 433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest container for your SageMaker endpoint.

# %%
bucket_name = ' ------ ' # <--- CHANGE - to be the bucket name
s3 = boto3.resource('s3')
my_region = boto3.session.Session().region_name # set the region of the instance

try:
    if  my_region == 'us-east-1':
        s3.create_bucket(Bucket=bucket_name)
    else: 
        s3.create_bucket(Bucket=bucket_name, CreateBucketConfiguration={ 'LocationConstraint': my_region })
    print('S3 bucket created successfully')
except Exception as e:
    print('S3 error: ',e)
# Out:
# S3 error:  An error occurred (BucketAlreadyOwnedByYou) when calling the CreateBucket operation: Your previous request to create the named bucket succeeded and you already own it.

# %%
try:
    s3.Bucket(bucket_name).download_file('', 'covid.csv')
except Exception as e:
    print('Data load error: ',e)

try:
    covid_df = pd.read_csv('./covid.csv',index_col=0)
    print('Success: Data loaded into dataframe.')
except Exception as e:
    print('Data load error: ',e)
# Out:
# Data load error:  Parameter validation failed:
# Invalid length for parameter Key, value: 0, valid range: 1-inf
# Success: Data loaded into dataframe.

# %%
covid_df.columns
# Out:
# Index(['sex', 'patient_type', 'entry_date', 'date_symptoms', 'date_died',
#        'intubed', 'pneumonia', 'age', 'pregnancy', 'diabetes', 'copd',
#        'asthma', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular',
#        'obesity', 'renal_chronic', 'tobacco', 'contact_other_covid',
#        'covid_res', 'icu'],
#       dtype='object')

# %%
columns_to_drop_above_97=[
       'intubed', 'pneumonia', 'pregnancy', 'diabetes', 'copd',
       'asthma', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular',
       'obesity', 'renal_chronic', 'tobacco', 'contact_other_covid',
       'covid_res', 'icu']

for col in columns_to_drop_above_97:
    covid_df = covid_df[covid_df[col]<97]

# %%
# reset index after tweaking dataframe
covid_df = covid_df.reset_index(drop=True)

length_of_lesser_data = covid_df.loc[covid_df.intubed == 1, 'intubed'].count()

# %%
# drop data to make the amounts equal

length_of_same_data = covid_df.loc[covid_df.intubed == 2, 'intubed'].count()
length = length_of_same_data - length_of_lesser_data


covid_df = covid_df.drop(covid_df.intubed[covid_df.intubed.eq(2)].sample(length).index )

# %%
# check they are equal 
length_of_lesser_data = covid_df.loc[covid_df.intubed == 1, 'intubed'].count()
print(length_of_lesser_data)

length_of_more_data = covid_df.loc[covid_df.intubed == 2, 'intubed'].count()
print(length_of_more_data)
# Out:
# 2561
# 2561

# %%
# did they die and add this as a column 
covid_df['Died?'] = covid_df['date_died'].apply(lambda x: 1 if x == '9999-99-99' else 2)

# %%
# Select feature columns and column of target prediction
columns_to_train=['sex', 'age','pneumonia', 'diabetes', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular',
       'obesity']
column_class=["intubed"]

# %%
import sagemaker.amazon.common as smac

split_train = int(len(covid_df) * 0.8)
split_test = int(len(covid_df) * 0.2)
print(split_train)
print(split_test)

# shuffle data
covid_df = covid_df.sample(frac=1, random_state=1729).reset_index(drop=True)

x_train = covid_df[columns_to_train][split_test:split_train].to_numpy().astype('float32')
y_train = np.where(covid_df["intubed"][split_test:split_train].to_numpy() == 1, 0, 1).astype('float32')
x_test = covid_df[columns_to_train][:split_test].to_numpy().astype('float32')
y_test = np.where(covid_df["intubed"][:split_test] == 1, 0, 1).astype('float32')

print(len(y_train)) 
print(len(y_test))
# Out:
# 4097
# 1024
# 3073
# 1024

# %%
train_buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(train_buf, x_train, y_train)
train_buf.seek(0)

val_buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(val_buf, x_test, y_test)
val_buf.seek(0)

bucket = 'wwcode-data-hack-bridgeclub' # <--- CHANGE - to be the bucket name
prefix = 'wwcode-covid'                # <--- CHANGE - to be folder name
train_key = 'training-data'         
val_key = 'val-data'      

boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', train_key)).upload_fileobj(train_buf)
s3_train_data = 's3://{}/{}/train/{}'.format(bucket, prefix, train_key)
print('uploaded training data location: {}'.format(s3_train_data))

boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'val', val_key)).upload_fileobj(val_buf)
s3_val_data = 's3://{}/{}/val/{}'.format(bucket, prefix, val_key)
print('uploaded training data location: {}'.format(s3_val_data))

# %%
output_location = 's3://{}/{}/output'.format(bucket, prefix)
print('training artifacts will be uploaded to: {}'.format(output_location))

# %%
import boto3
import sagemaker

from sagemaker.amazon.amazon_estimator import get_image_uri
container = get_image_uri(boto3.Session().region_name, 'linear-learner')

sess = sagemaker.Session()

linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.m4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sess)
linear.set_hyperparameters(feature_dim=len(columns_to_train),
                           predictor_type='binary_classifier',
                           mini_batch_size=200)

linear.fit({'train': s3_train_data, 'validation': s3_val_data})
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2020-08-12 18:59:50 Starting - Starting the training job...
# 2020-08-12 18:59:54 Starting - Launching requested ML instances.........
# 2020-08-12 19:01:28 Starting - Preparing the instances for training......
# 2020-08-12 19:02:39 Downloading - Downloading input data......
# 2020-08-12 19:03:42 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [08/12/2020 19:03:46 INFO 139816794826560] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [08/12/2020 19:03:46 INFO 139816794826560] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'9', u'mini_batch_size': u'200', u'predictor_type': u'binary_classifier'}
# [08/12/2020 19:03:46 INFO 139816794826560] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'9', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'200', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [08/12/2020 19:03:46 WARNING 139816794826560] Loggers have already been setup.
# Process 1 is a worker.
# [08/12/2020 19:03:46 INFO 139816794826560] Using default worker.
# [08/12/2020 19:03:46 INFO 139816794826560] Checkpoint loading and saving are disabled.
# [2020-08-12 19:03:46.827] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-08-12 19:03:46.849] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 23, "num_examples": 1, "num_bytes": 16000}
# [08/12/2020 19:03:46 INFO 139816794826560] Create Store: local
# [2020-08-12 19:03:46.898] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 48, "num_examples": 16, "num_bytes": 245840}
# [08/12/2020 19:03:46 INFO 139816794826560] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f29438be410>
# [08/12/2020 19:03:46 INFO 139816794826560] Scaling model computed with parameters:
#  {'stdev_weight':
# [ 1.         21.228117    0.42708308  0.47279972  0.20657094  0.4805788
#   0.22732846  0.2260177   0.44079927]
# <NDArray 9 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 1.        51.34833    1.24       1.6626667  1.9553334  1.638
#   1.9453334  1.946      1.736    ]
# <NDArray 9 @cpu(0)>}
# [08/12/2020 19:03:46 INFO 139816794826560] nvidia-smi took: 0.0251040458679 secs to identify 0 gpus
# [08/12/2020 19:03:46 INFO 139816794826560] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 16, "sum": 16.0, "min": 16}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 17, "sum": 17.0, "min": 17}, "Total Records Seen": {"count": 1, "max": 3273, "sum": 3273.0, "min": 3273}, "Max Records Seen Between Resets": {"count": 1, "max": 3073, "sum": 3073.0, "min": 3073}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1597259027.003878, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1597259027.003836}
#
# [2020-08-12 19:03:47.423] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 419, "num_examples": 16, "num_bytes": 245840}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6792097473144532, "sum": 0.6792097473144532, "min": 0.6792097473144532}}, "EndTime": 1597259027.42388, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.423779}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6944819488525391, "sum": 0.6944819488525391, "min": 0.6944819488525391}}, "EndTime": 1597259027.423991, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.423968}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6789323069254557, "sum": 0.6789323069254557, "min": 0.6789323069254557}}, "EndTime": 1597259027.424068, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.42405}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6782725067138672, "sum": 0.6782725067138672, "min": 0.6782725067138672}}, "EndTime": 1597259027.424122, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.424105}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6679058507283528, "sum": 0.6679058507283528, "min": 0.6679058507283528}}, "EndTime": 1597259027.424184, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.424166}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6694519322713216, "sum": 0.6694519322713216, "min": 0.6694519322713216}}, "EndTime": 1597259027.424252, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.424235}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6682312189737956, "sum": 0.6682312189737956, "min": 0.6682312189737956}}, "EndTime": 1597259027.42431, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.424293}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6661526769002278, "sum": 0.6661526769002278, "min": 0.6661526769002278}}, "EndTime": 1597259027.424378, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.424361}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6849753011067709, "sum": 0.6849753011067709, "min": 0.6849753011067709}}, "EndTime": 1597259027.424437, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.424424}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6962350362141927, "sum": 0.6962350362141927, "min": 0.6962350362141927}}, "EndTime": 1597259027.424501, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.424483}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6898726145426433, "sum": 0.6898726145426433, "min": 0.6898726145426433}}, "EndTime": 1597259027.424562, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.424545}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6769976348876953, "sum": 0.6769976348876953, "min": 0.6769976348876953}}, "EndTime": 1597259027.424623, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.424607}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6669576466878255, "sum": 0.6669576466878255, "min": 0.6669576466878255}}, "EndTime": 1597259027.424686, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.424668}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6672534790039063, "sum": 0.6672534790039063, "min": 0.6672534790039063}}, "EndTime": 1597259027.424748, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.42473}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6663405685424805, "sum": 0.6663405685424805, "min": 0.6663405685424805}}, "EndTime": 1597259027.424843, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.424823}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.666981674194336, "sum": 0.666981674194336, "min": 0.666981674194336}}, "EndTime": 1597259027.424914, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.424897}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6947059173583985, "sum": 0.6947059173583985, "min": 0.6947059173583985}}, "EndTime": 1597259027.424975, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.424958}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6832244720458984, "sum": 0.6832244720458984, "min": 0.6832244720458984}}, "EndTime": 1597259027.425046, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.425027}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6777246754964192, "sum": 0.6777246754964192, "min": 0.6777246754964192}}, "EndTime": 1597259027.425119, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.4251}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.693200932820638, "sum": 0.693200932820638, "min": 0.693200932820638}}, "EndTime": 1597259027.42519, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.425172}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6878092600504557, "sum": 0.6878092600504557, "min": 0.6878092600504557}}, "EndTime": 1597259027.425264, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.425247}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.686900889078776, "sum": 0.686900889078776, "min": 0.686900889078776}}, "EndTime": 1597259027.425319, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.425304}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.687798828125, "sum": 0.687798828125, "min": 0.687798828125}}, "EndTime": 1597259027.425381, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.425364}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6871324717203776, "sum": 0.6871324717203776, "min": 0.6871324717203776}}, "EndTime": 1597259027.425452, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.425435}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6950774281819662, "sum": 0.6950774281819662, "min": 0.6950774281819662}}, "EndTime": 1597259027.425514, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.425497}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6922283426920572, "sum": 0.6922283426920572, "min": 0.6922283426920572}}, "EndTime": 1597259027.425584, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.425566}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7009616495768229, "sum": 0.7009616495768229, "min": 0.7009616495768229}}, "EndTime": 1597259027.425655, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.425637}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6919818216959636, "sum": 0.6919818216959636, "min": 0.6919818216959636}}, "EndTime": 1597259027.425725, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.425708}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.709788579305013, "sum": 0.709788579305013, "min": 0.709788579305013}}, "EndTime": 1597259027.425786, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.42577}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7108230183919271, "sum": 0.7108230183919271, "min": 0.7108230183919271}}, "EndTime": 1597259027.42585, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.425833}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7098797556559244, "sum": 0.7098797556559244, "min": 0.7098797556559244}}, "EndTime": 1597259027.425911, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.425893}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7096920572916666, "sum": 0.7096920572916666, "min": 0.7096920572916666}}, "EndTime": 1597259027.426025, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.426005}
#
# [08/12/2020 19:03:47 INFO 139816794826560] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.679209747314
# [2020-08-12 19:03:47.446] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 0, "duration": 619, "num_examples": 1, "num_bytes": 16000}
# [2020-08-12 19:03:47.677] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 2, "duration": 230, "num_examples": 6, "num_bytes": 81920}
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6685962714254856, "sum": 0.6685962714254856, "min": 0.6685962714254856}}, "EndTime": 1597259027.957285, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.957182}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6824744753539562, "sum": 0.6824744753539562, "min": 0.6824744753539562}}, "EndTime": 1597259027.957384, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.957363}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6688073705881834, "sum": 0.6688073705881834, "min": 0.6688073705881834}}, "EndTime": 1597259027.957449, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.957431}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6687998101115227, "sum": 0.6687998101115227, "min": 0.6687998101115227}}, "EndTime": 1597259027.957517, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.957499}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6554613336920738, "sum": 0.6554613336920738, "min": 0.6554613336920738}}, "EndTime": 1597259027.957585, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.957568}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6500631496310234, "sum": 0.6500631496310234, "min": 0.6500631496310234}}, "EndTime": 1597259027.957645, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.957628}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6510429959744215, "sum": 0.6510429959744215, "min": 0.6510429959744215}}, "EndTime": 1597259027.957709, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.957697}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6482813991606236, "sum": 0.6482813991606236, "min": 0.6482813991606236}}, "EndTime": 1597259027.957745, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.957737}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6729471161961555, "sum": 0.6729471161961555, "min": 0.6729471161961555}}, "EndTime": 1597259027.957778, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.95777}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6813916005194187, "sum": 0.6813916005194187, "min": 0.6813916005194187}}, "EndTime": 1597259027.957831, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.957821}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6779736131429672, "sum": 0.6779736131429672, "min": 0.6779736131429672}}, "EndTime": 1597259027.957887, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.957876}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6666413731873035, "sum": 0.6666413731873035, "min": 0.6666413731873035}}, "EndTime": 1597259027.957947, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.957933}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6516812164336443, "sum": 0.6516812164336443, "min": 0.6516812164336443}}, "EndTime": 1597259027.958007, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.95799}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6548476181924343, "sum": 0.6548476181924343, "min": 0.6548476181924343}}, "EndTime": 1597259027.958069, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.958052}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6488090474158525, "sum": 0.6488090474158525, "min": 0.6488090474158525}}, "EndTime": 1597259027.95811, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.958095}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6483928114175797, "sum": 0.6483928114175797, "min": 0.6483928114175797}}, "EndTime": 1597259027.958168, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.958151}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6838410869240761, "sum": 0.6838410869240761, "min": 0.6838410869240761}}, "EndTime": 1597259027.958226, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.958211}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6747265569865704, "sum": 0.6747265569865704, "min": 0.6747265569865704}}, "EndTime": 1597259027.958292, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.958274}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6702574361115694, "sum": 0.6702574361115694, "min": 0.6702574361115694}}, "EndTime": 1597259027.95836, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.958342}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.682798957452178, "sum": 0.682798957452178, "min": 0.682798957452178}}, "EndTime": 1597259027.958424, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.958406}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6919869910925627, "sum": 0.6919869910925627, "min": 0.6919869910925627}}, "EndTime": 1597259027.958498, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.958479}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6870923060923815, "sum": 0.6870923060923815, "min": 0.6870923060923815}}, "EndTime": 1597259027.958568, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.958551}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6889691241085529, "sum": 0.6889691241085529, "min": 0.6889691241085529}}, "EndTime": 1597259027.958631, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.958614}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6890058759599924, "sum": 0.6890058759599924, "min": 0.6890058759599924}}, "EndTime": 1597259027.958693, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.958676}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6915371045470238, "sum": 0.6915371045470238, "min": 0.6915371045470238}}, "EndTime": 1597259027.958746, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.958735}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6925458963960409, "sum": 0.6925458963960409, "min": 0.6925458963960409}}, "EndTime": 1597259027.958799, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.958783}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6913936659693718, "sum": 0.6913936659693718, "min": 0.6913936659693718}}, "EndTime": 1597259027.958852, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.958837}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6929163336753845, "sum": 0.6929163336753845, "min": 0.6929163336753845}}, "EndTime": 1597259027.958911, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.958895}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7091063838452101, "sum": 0.7091063838452101, "min": 0.7091063838452101}}, "EndTime": 1597259027.958971, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.958954}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.722465867176652, "sum": 0.722465867176652, "min": 0.722465867176652}}, "EndTime": 1597259027.959033, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.959017}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7056418675929308, "sum": 0.7056418675929308, "min": 0.7056418675929308}}, "EndTime": 1597259027.959087, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.959072}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7097410429269075, "sum": 0.7097410429269075, "min": 0.7097410429269075}}, "EndTime": 1597259027.959142, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.95913}
#
# [08/12/2020 19:03:47 INFO 139816794826560] #quality_metric: host=algo-1, epoch=0, validation binary_classification_cross_entropy_objective <loss>=0.668596271425
# [08/12/2020 19:03:47 INFO 139816794826560] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=sampled_accuracy, value=0.6484375
# [08/12/2020 19:03:47 INFO 139816794826560] Epoch 0: Loss improved. Updating best model
# [08/12/2020 19:03:47 INFO 139816794826560] Saving model for epoch: 0
# [08/12/2020 19:03:47 INFO 139816794826560] Saved checkpoint to "/tmp/tmppm8Pus/mx-mod-0000.params"
# [08/12/2020 19:03:47 INFO 139816794826560] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 16, "sum": 16.0, "min": 16}, "Number of Batches Since Last Reset": {"count": 1, "max": 16, "sum": 16.0, "min": 16}, "Number of Records Since Last Reset": {"count": 1, "max": 3073, "sum": 3073.0, "min": 3073}, "Total Batches Seen": {"count": 1, "max": 33, "sum": 33.0, "min": 33}, "Total Records Seen": {"count": 1, "max": 6346, "sum": 6346.0, "min": 6346}, "Max Records Seen Between Resets": {"count": 1, "max": 3073, "sum": 3073.0, "min": 3073}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1597259027.968769, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597259027.004146}
#
# [08/12/2020 19:03:47 INFO 139816794826560] #throughput_metric: host=algo-1, train throughput=3185.19912647 records/second
# [2020-08-12 19:03:48.394] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 424, "num_examples": 16, "num_bytes": 245840}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6666898956298828, "sum": 0.6666898956298828, "min": 0.6666898956298828}}, "EndTime": 1597259028.394349, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597259028.394232}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6792086130777995, "sum": 0.6792086130777995, "min": 0.6792086130777995}}, "EndTime": 1597259028.394462, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597259028.39444}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6667872060139974, "sum": 0.6667872060139974, "min": 0.6667872060139974}}, "EndTime": 1597259028.394546, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597259028.394526}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.665518539428711, "sum": 0.665518539428711, "min": 0.665518539428711}}, "EndTime": 1597259028.394617, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597259028.394598}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.
"Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.741944}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6239195875823498, "sum": 0.6239195875823498, "min": 0.6239195875823498}}, "EndTime": 1597259040.742026, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.742009}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6231259712949395, "sum": 0.6231259712949395, "min": 0.6231259712949395}}, "EndTime": 1597259040.742089, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.742072}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6239761095494032, "sum": 0.6239761095494032, "min": 0.6239761095494032}}, "EndTime": 1597259040.74215, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.742133}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.668545987457037, "sum": 0.668545987457037, "min": 0.668545987457037}}, "EndTime": 1597259040.742194, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.742184}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6684808470308781, "sum": 0.6684808470308781, "min": 0.6684808470308781}}, "EndTime": 1597259040.742232, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.742223}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6685018092393875, "sum": 0.6685018092393875, "min": 0.6685018092393875}}, "EndTime": 1597259040.742288, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.742271}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6685249339789152, "sum": 0.6685249339789152, "min": 0.6685249339789152}}, "EndTime": 1597259040.742351, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.742333}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6712079457938671, "sum": 0.6712079457938671, "min": 0.6712079457938671}}, "EndTime": 1597259040.742415, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.742399}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6692891847342253, "sum": 0.6692891847342253, "min": 0.6692891847342253}}, "EndTime": 1597259040.742479, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.742462}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6701171156018972, "sum": 0.6701171156018972, "min": 0.6701171156018972}}, "EndTime": 1597259040.742536, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.742523}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6690279431641102, "sum": 0.6690279431641102, "min": 0.6690279431641102}}, "EndTime": 1597259040.742591, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.74258}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6931151058524847, "sum": 0.6931151058524847, "min": 0.6931151058524847}}, "EndTime": 1597259040.742629, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.74262}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6930483877658844, "sum": 0.6930483877658844, "min": 0.6930483877658844}}, "EndTime": 1597259040.742665, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.742656}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6930526457726955, "sum": 0.6930526457726955, "min": 0.6930526457726955}}, "EndTime": 1597259040.742701, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.742693}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6930197812616825, "sum": 0.6930197812616825, "min": 0.6930197812616825}}, "EndTime": 1597259040.742752, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.742736}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6928726546466351, "sum": 0.6928726546466351, "min": 0.6928726546466351}}, "EndTime": 1597259040.742792, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.742783}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6932807210832834, "sum": 0.6932807210832834, "min": 0.6932807210832834}}, "EndTime": 1597259040.742828, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.74282}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6927848812192678, "sum": 0.6927848812192678, "min": 0.6927848812192678}}, "EndTime": 1597259040.742864, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.742856}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6932687982916832, "sum": 0.6932687982916832, "min": 0.6932687982916832}}, "EndTime": 1597259040.7429, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259040.742888}
#
# [08/12/2020 19:04:00 INFO 139816794826560] #quality_metric: host=algo-1, epoch=14, validation binary_classification_cross_entropy_objective <loss>=0.624013699591
# [08/12/2020 19:04:00 INFO 139816794826560] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=sampled_accuracy, value=0.6533203125
# [08/12/2020 19:04:00 INFO 139816794826560] Epoch 14: Loss improved. Updating best model
# [08/12/2020 19:04:00 INFO 139816794826560] Saving model for epoch: 14
# [08/12/2020 19:04:00 INFO 139816794826560] Saved checkpoint to "/tmp/tmpZARY2S/mx-mod-0000.params"
# [08/12/2020 19:04:00 INFO 139816794826560] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 16, "sum": 16.0, "min": 16}, "Number of Batches Since Last Reset": {"count": 1, "max": 16, "sum": 16.0, "min": 16}, "Number of Records Since Last Reset": {"count": 1, "max": 3073, "sum": 3073.0, "min": 3073}, "Total Batches Seen": {"count": 1, "max": 257, "sum": 257.0, "min": 257}, "Total Records Seen": {"count": 1, "max": 49368, "sum": 49368.0, "min": 49368}, "Max Records Seen Between Resets": {"count": 1, "max": 3073, "sum": 3073.0, "min": 3073}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1597259040.749411, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1597259039.876394}
#
# [08/12/2020 19:04:00 INFO 139816794826560] #throughput_metric: host=algo-1, train throughput=3519.40894686 records/second
# [08/12/2020 19:04:00 WARNING 139816794826560] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [08/12/2020 19:04:00 WARNING 139816794826560] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-08-12 19:04:00.977] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 47, "duration": 207, "num_examples": 6, "num_bytes": 81920}
# [08/12/2020 19:04:01 INFO 139816794826560] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=sampled_accuracy, value=0.6533203125
# [08/12/2020 19:04:01 INFO 139816794826560] Epoch 14: Loss improved. Updating best model
# [2020-08-12 19:04:01.218] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 49, "duration": 19, "num_examples": 6, "num_bytes": 81920}
# [08/12/2020 19:04:01 INFO 139816794826560] #validation_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.6223592571914196)
# [08/12/2020 19:04:01 INFO 139816794826560] #validation_score (algo-1) : ('binary_classification_accuracy', 0.6513671875)
# [08/12/2020 19:04:01 INFO 139816794826560] #validation_score (algo-1) : ('binary_f_1.000', 0.6020066889632107)
# [08/12/2020 19:04:01 INFO 139816794826560] #validation_score (algo-1) : ('precision', 0.7180851063829787)
# [08/12/2020 19:04:01 INFO 139816794826560] #validation_score (algo-1) : ('recall', 0.5182341650671785)
# [08/12/2020 19:04:01 INFO 139816794826560] #validation_score (algo-1) : ('roc_auc_score', 0.6859705490664458)
# [08/12/2020 19:04:01 INFO 139816794826560] #quality_metric: host=algo-1, validation binary_classification_cross_entropy_objective <loss>=0.622359257191
# [08/12/2020 19:04:01 INFO 139816794826560] #quality_metric: host=algo-1, validation binary_classification_accuracy <score>=0.6513671875
# [08/12/2020 19:04:01 INFO 139816794826560] #quality_metric: host=algo-1, validation binary_f_1.000 <score>=0.602006688963
# [08/12/2020 19:04:01 INFO 139816794826560] #quality_metric: host=algo-1, validation precision <score>=0.718085106383
# [08/12/2020 19:04:01 INFO 139816794826560] #quality_metric: host=algo-1, validation recall <score>=0.518234165067
# [08/12/2020 19:04:01 INFO 139816794826560] #quality_metric: host=algo-1, validation roc_auc_score <score>=0.685970549066
# [08/12/2020 19:04:01 INFO 139816794826560] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [08/12/2020 19:04:01 INFO 139816794826560] Saved checkpoint to "/tmp/tmpTN9yOo/mx-mod-0000.params"
# [08/12/2020 19:04:01 INFO 139816794826560] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 14734.261989593506, "sum": 14734.261989593506, "min": 14734.261989593506}, "finalize.time": {"count": 1, "max": 474.60198402404785, "sum": 474.60198402404785, "min": 474.60198402404785}, "initialize.time": {"count": 1, "max": 175.5831241607666, "sum": 175.5831241607666, "min": 175.5831241607666}, "check_early_stopping.time": {"count": 16, "max": 1.2090206146240234, "sum": 16.281843185424805, "min": 0.8859634399414062}, "setuptime": {"count": 1, "max": 27.153968811035156, "sum": 27.153968811035156, "min": 27.153968811035156}, "update.time": {"count": 15, "max": 1136.2898349761963, "sum": 13694.947481155396, "min": 822.9489326477051}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1597259041.229809, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1597259026.824751}
#
#
# 2020-08-12 19:04:10 Uploading - Uploading generated training model
# 2020-08-12 19:04:10 Completed - Training job completed
# Training seconds: 91
# Billable seconds: 91

# %% [markdown]
# ### Turn it into an endpoint

# %%
predictor = linear.deploy(initial_instance_count=1,
                             instance_type='ml.t2.medium',
                             endpoint_name = ' ---------- ') # <--- INSERT - add endpoint name
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# -----------------!
