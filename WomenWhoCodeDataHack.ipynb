# %%
# import libraries
import boto3, re, sys, math, json, os, sagemaker, urllib.request
from sagemaker import get_execution_role
import numpy as np                                
import pandas as pd                               
import matplotlib.pyplot as plt                   
from IPython.display import Image                 
from IPython.display import display               
from time import gmtime, strftime                 
from sagemaker.predictor import csv_serializer   

# Define IAM role
role = get_execution_role()
prefix = 'sagemaker/DEMO-xgboost-dm'
containers = {'us-west-2': '433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest',
              'us-east-1': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
              'us-east-2': '825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest',
              'eu-west-1': '685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:latest'} # each region has its XGBoost container
my_region = boto3.session.Session().region_name # set the region of the instance
print("Success - the MySageMakerInstance is in the " + my_region + " region. You will use the " + containers[my_region] + " container for your SageMaker endpoint.")
# Out:
# Success - the MySageMakerInstance is in the us-west-2 region. You will use the 433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest container for your SageMaker endpoint.

# %%
bucket_name = '' # <--- CHANGE THIS VARIABLE TO A UNIQUE NAME FOR YOUR BUCKET
s3 = boto3.resource('s3')
try:
    if  my_region == 'us-east-1':
      s3.create_bucket(Bucket=bucket_name)
    else: 
      s3.create_bucket(Bucket=bucket_name, CreateBucketConfiguration={ 'LocationConstraint': my_region })
    print('S3 bucket created successfully')
except Exception as e:
    print('S3 error: ',e)
# Out:
# S3 bucket created successfully

# %%
try:
#   urllib.request.urlretrieve ("https://d1.awsstatic.com/tmt/build-train-deploy-machine-learning-model-sagemaker/bank_clean.27f01fbbdf43271788427f3682996ae29ceca05d.csv", "bank_clean.csv")
#   print('Success: downloaded bank_clean.csv.')
    s3.Bucket(bucket_name).download_file('', 'covid.csv')
except Exception as e:
  print('Data load error: ',e)

try:
  covid_df = pd.read_csv('./covid.csv',index_col=0)
  print('Success: Data loaded into dataframe.')
except Exception as e:
    print('Data load error: ',e)
# Out:
# Success: Data loaded into dataframe.

# %%
covid_df = model_data
covid_df.columns
# Out:
# Index(['sex', 'patient_type', 'entry_date', 'date_symptoms', 'date_died',
#        'intubed', 'pneumonia', 'age', 'pregnancy', 'diabetes', 'copd',
#        'asthma', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular',
#        'obesity', 'renal_chronic', 'tobacco', 'contact_other_covid',
#        'covid_res', 'icu'],
#       dtype='object')

# %%
columns_to_drop_above_97=[
       'intubed', 'pneumonia', 'pregnancy', 'diabetes', 'copd',
       'asthma', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular',
       'obesity', 'renal_chronic', 'tobacco', 'contact_other_covid',
       'covid_res', 'icu']

for col in columns_to_drop_above_97:
    covid_df = covid_df[covid_df[col]<97]

# %%
# did they die tho 
covid_df['Died?'] = covid_df['date_died'].apply(lambda x: 1 if x == '9999-99-99' else 2)

# %%
len(covid_df)
# Out:
# 23158

# %%
# Make array from 
columns_to_train=[ 'pneumonia', 'pregnancy', 'diabetes', 'copd',
       'asthma', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular',
       'obesity']
column_class=["intubed"]

# %%
x=covid_df[columns_to_train].to_numpy()
y=covid_df["intubed"].to_numpy()

# %%
vectors = np.array(x
                  ).astype('float32')

# %%
labels = np.where(np.array(y) == 0, 1, 0).astype('float32')

# %%
import sagemaker.amazon.common as smac

buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf, vectors, labels)
buf.seek(0)
# Out:
# 0

# %%
import boto3
import os

bucket = ''
prefix = 'wwcode-covid'
key = 'training-data'
boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', key)).upload_fileobj(buf)
s3_train_data = 's3://{}/{}/train/{}'.format(bucket, prefix, key)
print('uploaded training data location: {}'.format(s3_train_data))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-4ef3f44de1e7> in <module>
#       5 prefix = 'wwcode-covid'
#       6 key = 'training-data'
# ----> 7 boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', key)).upload_fileobj(buf)
#       8 s3_train_data = 's3://{}/{}/train/{}'.format(bucket, prefix, key)
#       9 print('uploaded training data location: {}'.format(s3_train_data))
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/s3/inject.py in object_upload_fileobj(self, Fileobj, ExtraArgs, Callback, Config)
#     619     return self.meta.client.upload_fileobj(
#     620         Fileobj=Fileobj, Bucket=self.bucket_name, Key=self.key,
# --> 621         ExtraArgs=ExtraArgs, Callback=Callback, Config=Config)
#     622
#     623
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/s3/inject.py in upload_fileobj(self, Fileobj, Bucket, Key, ExtraArgs, Callback, Config)
#     537             fileobj=Fileobj, bucket=Bucket, key=Key,
#     538             extra_args=ExtraArgs, subscribers=subscribers)
# --> 539         return future.result()
#     540
#     541
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/s3transfer/futures.py in result(self)
#     104             # however if a KeyboardInterrupt is raised we want want to exit
#     105             # out of this and propogate the exception.
# --> 106             return self._coordinator.result()
#     107         except KeyboardInterrupt as e:
#     108             self.cancel()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/s3transfer/futures.py in result(self)
#     263         # final result.
#     264         if self._exception:
# --> 265             raise self._exception
#     266         return self._result
#     267
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/s3transfer/tasks.py in _main(self, transfer_future, **kwargs)
#     253             # Call the submit method to start submitting tasks to execute the
#     254             # transfer.
# --> 255             self._submit(transfer_future=transfer_future, **kwargs)
#     256         except BaseException as e:
#     257             # If there was an exception raised during the submission of task
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/s3transfer/upload.py in _submit(self, client, config, osutil, request_executor, transfer_future, bandwidth_limiter)
#     542         """
#     543         upload_input_manager = self._get_upload_input_manager_cls(
# --> 544             transfer_future)(
#     545                 osutil, self._transfer_coordinator, bandwidth_limiter)
#     546
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/s3transfer/upload.py in _get_upload_input_manager_cls(self, transfer_future)
#     515         fileobj = transfer_future.meta.call_args.fileobj
#     516         for upload_manager_cls in upload_manager_resolver_chain:
# --> 517             if upload_manager_cls.is_compatible(fileobj):
#     518                 return upload_manager_cls
#     519         raise RuntimeError(
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/s3transfer/upload.py in is_compatible(cls, upload_source)
#     308     @classmethod
#     309     def is_compatible(cls, upload_source):
# --> 310         return readable(upload_source) and seekable(upload_source)
#     311
#     312     def stores_body_in_memory(self, operation_name):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/s3transfer/compat.py in readable(fileobj)
#      87     """
#      88     if hasattr(fileobj, 'readable'):
# ---> 89         return fileobj.readable()
#      90
#      91     return hasattr(fileobj, 'read')
#
# ValueError: I/O operation on closed file.

# %%
output_location = 's3://{}/{}/output'.format(bucket, prefix)
print('training artifacts will be uploaded to: {}'.format(output_location))
# Out:
# training artifacts will be uploaded to: s3://wwcode-data-hack-bridgeclub/wwcode-covid/output

# %%
import boto3
import sagemaker

from sagemaker.amazon.amazon_estimator import get_image_uri
container = get_image_uri(boto3.Session().region_name, 'linear-learner')
import os

sess = sagemaker.Session()

linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.c4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sess)
linear.set_hyperparameters(feature_dim=10,
                           predictor_type='binary_classifier',
                           mini_batch_size=200)

linear.fit({'train': s3_train_data})
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2020-08-09 18:34:41 Starting - Starting the training job...
# 2020-08-09 18:34:43 Starting - Launching requested ML instances......
# 2020-08-09 18:36:08 Starting - Preparing the instances for training.........
# 2020-08-09 18:37:25 Downloading - Downloading input data...
# 2020-08-09 18:38:08 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [08/09/2020 18:38:12 INFO 139978268763968] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [08/09/2020 18:38:12 INFO 139978268763968] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'10', u'mini_batch_size': u'200', u'predictor_type': u'binary_classifier'}
# [08/09/2020 18:38:12 INFO 139978268763968] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'10', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'200', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [08/09/2020 18:38:12 WARNING 139978268763968] Loggers have already been setup.
# Process 1 is a worker.
# [08/09/2020 18:38:12 INFO 139978268763968] Using default worker.
# [08/09/2020 18:38:13 INFO 139978268763968] Checkpoint loading and saving are disabled.
# [2020-08-09 18:38:13.151] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 15, "num_examples": 1, "num_bytes": 16800}
# [08/09/2020 18:38:13 INFO 139978268763968] Create Store: local
# [2020-08-09 18:38:13.283] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 131, "num_examples": 51, "num_bytes": 856800}
# [08/09/2020 18:38:13 INFO 139978268763968] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f4ee46131d0>
# [08/09/2020 18:38:13 INFO 139978268763968] Scaling model computed with parameters:
#  {'stdev_weight':
# [0.43673918 0.13555385 0.4694992  0.19457257 0.17432244 0.16703394
#  0.47977048 0.17246631 0.20901701 0.44690862]
# <NDArray 10 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [1
"Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596998296.754575}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010949978704017628, "sum": 0.010949978704017628, "min": 0.010949978704017628}}, "EndTime": 1596998296.75465, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596998296.754634}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.18207466225002122, "sum": 0.18207466225002122, "min": 0.18207466225002122}}, "EndTime": 1596998296.754706, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596998296.754695}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1794368553161621, "sum": 0.1794368553161621, "min": 0.1794368553161621}}, "EndTime": 1596998296.754765, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596998296.754748}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1822021023708841, "sum": 0.1822021023708841, "min": 0.1822021023708841}}, "EndTime": 1596998296.754819, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596998296.754809}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1794021053314209, "sum": 0.1794021053314209, "min": 0.1794021053314209}}, "EndTime": 1596998296.754871, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596998296.754855}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01103795677650234, "sum": 0.01103795677650234, "min": 0.01103795677650234}}, "EndTime": 1596998296.754926, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596998296.754915}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011148296974538624, "sum": 0.011148296974538624, "min": 0.011148296974538624}}, "EndTime": 1596998296.754977, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596998296.754962}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011100862968510584, "sum": 0.011100862968510584, "min": 0.011100862968510584}}, "EndTime": 1596998296.755025, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596998296.755014}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011118360047593066, "sum": 0.011118360047593066, "min": 0.011118360047593066}}, "EndTime": 1596998296.755064, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596998296.75505}
#
# [08/09/2020 18:38:16 INFO 139978268763968] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.181164423528
# [08/09/2020 18:38:16 INFO 139978268763968] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.010949978704
# [08/09/2020 18:38:16 INFO 139978268763968] Epoch 0: Loss improved. Updating best model
# [08/09/2020 18:38:16 INFO 139978268763968] Saving model for epoch: 0
# [08/09/2020 18:38:16 INFO 139978268763968] Saved checkpoint to "/tmp/tmp2Lyet0/mx-mod-0000.params"
# [08/09/2020 18:38:16 INFO 139978268763968] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 116, "sum": 116.0, "min": 116}, "Number of Batches Since Last Reset": {"count": 1, "max": 116, "sum": 116.0, "min": 116}, "Number of Records Since Last Reset": {"count": 1, "max": 23158, "sum": 23158.0, "min": 23158}, "Total Batches Seen": {"count": 1, "max": 168, "sum": 168.0, "min": 168}, "Total Records Seen": {"count": 1, "max": 33558, "sum": 33558.0, "min": 33558}, "Max Records Seen Between Resets": {"count": 1, "max": 23158, "sum": 23158.0, "min": 23158}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1596998296.766168, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596998293.380731}
#
# [08/09/2020 18:38:16 INFO 139978268763968] #throughput_metric: host=algo-1, train throughput=6840.28360605 records/second
# [2020-08-09 18:38:20.531] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 3765, "num_examples": 116, "num_bytes": 1945272}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02832259240357772, "sum": 0.02832259240357772, "min": 0.02832259240357772}}, "EndTime": 1596998300.532079, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596998300.531971}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02577355204457822, "sum": 0.02577355204457822, "min": 0.02577355204457822}}, "EndTime": 1596998300.532197, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596998300.532174}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02832415412819904, "sum": 0.02832415412819904, "min": 0.02832415412819904}}, "EndTime": 1596998300.532263, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596998300.532245}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.025754343862118927, "sum": 0.025754343862118927, "min": 0.025754343862118927}}, "EndTime": 1596998300.53233, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596998300.532311}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 3.588868786945291e-05, "sum": 3.588868786945291e-05, "min": 3.588868786945291e-05}}, "EndTime": 1596998300.532388, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596998300.532372}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 3.376957029104233e-05, "sum": 3.376957029104233e-05, "min": 3.376957029104233e-05}}, "EndTime": 1596998300.532459, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596998300.532442}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 3.6080844011967595e-05, "sum": 3.6080844011967595e-05, "min": 3.6080844011967595e-05}}, "EndTime": 1596998300.532522, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596998300.532504}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 3.343879759473645e-05, "sum": 3.343879759473645e-05, "min": 3.343879759473645e-05}}, "EndTime": 1596998300.532584, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596998300.532567}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0
#progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 116, "sum": 116.0, "min": 116}, "Number of Batches Since Last Reset": {"count": 1, "max": 116, "sum": 116.0, "min": 116}, "Number of Records Since Last Reset": {"count": 1, "max": 23158, "sum": 23158.0, "min": 23158}, "Total Batches Seen": {"count": 1, "max": 284, "sum": 284.0, "min": 284}, "Total Records Seen": {"count": 1, "max": 56716, "sum": 56716.0, "min": 56716}, "Max Records Seen Between Resets": {"count": 1, "max": 23158, "sum": 23158.0, "min": 23158}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1596998300.541867, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596998296.766438}
#
# [08/09/2020 18:38:20 INFO 139978268763968] #throughput_metric: host=algo-1, train throughput=6133.65631549 records/second
# [2020-08-09 18:38:23.800] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 3258, "num_examples": 116, "num_bytes": 1945272}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014064448252968166, "sum": 0.014064448252968166, "min": 0.014064448252968166}}, "EndTime": 1596998303.800877, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.800782}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011999538494193036, "sum": 0.011999538494193036, "min": 0.011999538494193036}}, "EndTime": 1596998303.800991, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.80097}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014064190252967504, "sum": 0.014064190252967504, "min": 0.014064190252967504}}, "EndTime": 1596998303.801063, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.801043}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012001233909441078, "sum": 0.012001233909441078, "min": 0.012001233909441078}}, "EndTime": 1596998303.801131, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.801112}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 3.161512505587028e-05, "sum": 3.161512505587028e-05, "min": 3.161512505587028e-05}}, "EndTime": 1596998303.801195, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.801177}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.949193330562633e-05, "sum": 2.949193330562633e-05, "min": 2.949193330562633e-05}}, "EndTime": 1596998303.801268, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.801249}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 3.2041656845451694e-05, "sum": 3.2041656845451694e-05, "min": 3.2041656845451694e-05}}, "EndTime": 1596998303.801341, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.801322}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.9408406223291936e-05, "sum": 2.9408406223291936e-05, "min": 2.9408406223291936e-05}}, "EndTime": 1596998303.80141, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.801392}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014082208985867707, "sum": 0.014082208985867707, "min": 0.014082208985867707}}, "EndTime": 1596998303.801486, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.801466}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012013542921646782, "sum": 0.012013542921646782, "min": 0.012013542921646782}}, "EndTime": 1596998303.80156, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.80154}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01409012766506361, "sum": 0.01409012766506361, "min": 0.01409012766506361}}, "EndTime": 1596998303.801626, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.801609}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012012221958326257, "sum": 0.012012221958326257, "min": 0.012012221958326257}}, "EndTime": 1596998303.801693, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.801675}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 3.12470939901212e-05, "sum": 3.12470939901212e-05, "min": 3.12470939901212e-05}}, "EndTime": 1596998303.801766, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.801748}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.9492787672611683e-05, "sum": 2.9492787672611683e-05, "min": 2.9492787672611683e-05}}, "EndTime": 1596998303.80184, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.801821}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 3.2236152733473676e-05, "sum": 3.2236152733473676e-05, "min": 3.2236152733473676e-05}}, "EndTime": 1596998303.801898, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.801881}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.9067018858926453e-05, "sum": 2.9067018858926453e-05, "min": 2.9067018858926453e-05}}, "EndTime": 1596998303.801961, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.801943}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014094263118246327, "sum": 0.014094263118246327, "min": 0.014094263118246327}}, "EndTime": 1596998303.802025, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.802007}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011994141542393229, "sum": 0.011994141542393229, "min": 0.011994141542393229}}, "EndTime": 1596998303.80208, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.802068}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014085575715355252, "sum": 0.014085575715355252, "min": 0.014085575715355252}}, "EndTime": 1596998303.802136, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.802121}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012017617163450822, "sum": 0.012017617163450822, "min": 0.012017617163450822}}, "EndTime": 1596998303.802175, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.802166}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 3.4727808776433054e-05, "sum": 3.4727808776433054e-05, "min": 3.4727808776433054e-05}}, "EndTime": 1596998303.80223, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.802214}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 3.239279141163697e-05, "sum": 3.239279141163697e-05, "min": 3.239279141163697e-05}}, "EndTime": 1596998303.802298, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.80228}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 3.4992952324935924e-05, "sum": 3.4992952324935924e-05, "min": 3.4992952324935924e-05}}, "EndTime": 1596998303.80237, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.802352}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 3.1973873953456466e-05, "sum": 3.1973873953456466e-05, "min": 3.1973873953456466e-05}}, "EndTime": 1596998303.802436, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.802418}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014022443159766819, "sum": 0.014022443159766819, "min": 0.014022443159766819}}, "EndTime": 1596998303.802498, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.802481}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011948038132294364, "sum": 0.011948038132294364, "min": 0.011948038132294364}}, "EndTime": 1596998303.802557, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.80254}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014030685196752133, "sum": 0.014030685196752133, "min": 0.014030685196752133}}, "EndTime": 1596998303.802621, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.802604}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011946165053740791, "sum": 0.011946165053740791, "min": 0.011946165053740791}}, "EndTime": 1596998303.802682, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.802665}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 3.536834276240805e-05, "sum": 3.536834276240805e-05, "min": 3.536834276240805e-05}}, "EndTime": 1596998303.802741, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.802724}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 3.279138562957878e-05, "sum": 3.279138562957878e-05, "min": 3.279138562957878e-05}}, "EndTime": 1596998303.802814, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.802797}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 3.4812828667623844e-05, "sum": 3.4812828667623844e-05, "min": 3.4812828667623844e-05}}, "EndTime": 1596998303.802888, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.802869}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 3.3032922033706436e-05, "sum": 3.3032922033706436e-05, "min": 3.3032922033706436e-05}}, "EndTime": 1596998303.802959, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998303.80294}
#
# [08/09/2020 18:38:23 INFO 139978268763968] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.014064448253
# [08/09/2020 18:38:23 INFO 139978268763968] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=2.90670188589e-05
# [08/09/2020 18:38:23 INFO 139978268763968] Epoch 2: Loss improved. Updating best model
# [08/09/2020 18:38:23 INFO 139978268763968] Saving model for epoch: 2
# [08/09/2020 18:38:23 INFO 139978268763968] Saved checkpoint to "/tmp/tmpde613M/mx-mod-0000.params"
# [08/09/2020 18:38:23 INFO 139978268763968] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 116, "sum": 116.0, "min": 116}, "Number of Batches Since Last Reset": {"count": 1, "max": 116, "sum": 116.0, "min": 116}, "Number of Records Since Last Reset": {"count": 1, "max": 23158, "sum": 23158.0, "min": 23158}, "Total Batches Seen": {"count": 1, "max": 400, "sum": 400.0, "min": 400}, "Total Records Seen": {"count": 1, "max": 79874, "sum": 79874.0, "min": 79874}, "Max Records Seen Between Resets": {"count": 1, "max": 23158, "sum": 23158.0, "min": 23158}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1596998303.811228, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1596998300.542136}
#
# [08/09/2020 18:38:23 INFO 139978268763968] #throughput_metric: host=algo-1, train throughput=7083.71170926 records/second
# [2020-08-09 18:38:27.235] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 3424, "num_examples": 116, "num_bytes": 1945272}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.009060815106267514, "sum": 0.009060815106267514, "min": 0.009060815106267514}}, "EndTime": 1596998307.235886, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1596998307.235777}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0072654339489729505, "sum": 0.0072654339489729505, "min": 0.0072654339489729505}}, "EndTime": 1596998307.235986, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1596998307.235967}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.009060275559839995, "sum": 0.009060275559839995, "min": 0.009060275559839995}}, "EndTime": 1596998307.236058, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1596998307.23604}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.007268426397572393, "sum": 0.007268426397572393, "min": 0.007268426397572393}}, "EndTime": 1596998307.236126, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1596998307.236107}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.8454177547246218e-05, "sum": 2.8454177547246218e-05, "min": 2.8454177547246218e-05}}, "EndTime": 1596998307.236191, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1596998307.236174}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.605327828179883e-05, "sum": 2.605327828179883e-05, "min": 2.605327828179883e-05}}, "EndTime": 1596998307.236274, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1596998307.236254}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0007815477556508521, "sum": 0.0007815477556508521, "min": 0.0007815477556508521}}, "EndTime": 1596998343.666223, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.666202}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.001854219139918037, "sum": 0.001854219139918037, "min": 0.001854219139918037}}, "EndTime": 1596998343.666293, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.666277}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0007821599199720051, "sum": 0.0007821599199720051, "min": 0.0007821599199720051}}, "EndTime": 1596998343.666373, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.666353}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 1.4858178510938001e-05, "sum": 1.4858178510938001e-05, "min": 1.4858178510938001e-05}}, "EndTime": 1596998343.66645, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.66643}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 8.226501148032105e-06, "sum": 8.226501148032105e-06, "min": 8.226501148032105e-06}}, "EndTime": 1596998343.666522, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.666503}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 1.4940854273331554e-05, "sum": 1.4940854273331554e-05, "min": 1.4940854273331554e-05}}, "EndTime": 1596998343.666587, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.66657}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 8.23848182335496e-06, "sum": 8.23848182335496e-06, "min": 8.23848182335496e-06}}, "EndTime": 1596998343.666663, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.666645}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.001867793963007305, "sum": 0.001867793963007305, "min": 0.001867793963007305}}, "EndTime": 1596998343.666743, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.666715}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0007870637521795605, "sum": 0.0007870637521795605, "min": 0.0007870637521795605}}, "EndTime": 1596998343.666804, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.666787}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0018696531549743983, "sum": 0.0018696531549743983, "min": 0.0018696531549743983}}, "EndTime": 1596998343.666869, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.666852}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0007868407342744911, "sum": 0.0007868407342744911, "min": 0.0007868407342744911}}, "EndTime": 1596998343.666918, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.666907}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 1.4987275186602188e-05, "sum": 1.4987275186602188e-05, "min": 1.4987275186602188e-05}}, "EndTime": 1596998343.666973, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.666957}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 8.246577608034663e-06, "sum": 8.246577608034663e-06, "min": 8.246577608034663e-06}}, "EndTime": 1596998343.667042, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.667024}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 1.525965212520374e-05, "sum": 1.525965212520374e-05, "min": 1.525965212520374e-05}}, "EndTime": 1596998343.667108, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.667089}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 8.157965575304368e-06, "sum": 8.157965575304368e-06, "min": 8.157965575304368e-06}}, "EndTime": 1596998343.667168, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.667157}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0018588340800741445, "sum": 0.0018588340800741445, "min": 0.0018588340800741445}}, "EndTime": 1596998343.667228, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.667211}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0007816156181304351, "sum": 0.0007816156181304351, "min": 0.0007816156181304351}}, "EndTime": 1596998343.667291, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.667273}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0018577188033124675, "sum": 0.0018577188033124675, "min": 0.0018577188033124675}}, "EndTime": 1596998343.667354, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.667337}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0007831309295218923, "sum": 0.0007831309295218923, "min": 0.0007831309295218923}}, "EndTime": 1596998343.667403, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.667391}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 1.5700601385501414e-05, "sum": 1.5700601385501414e-05, "min": 1.5700601385501414e-05}}, "EndTime": 1596998343.667463, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.667446}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 8.391679912481618e-06, "sum": 8.391679912481618e-06, "min": 8.391679912481618e-06}}, "EndTime": 1596998343.66753, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.667513}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 1.5882441976472088e-05, "sum": 1.5882441976472088e-05, "min": 1.5882441976472088e-05}}, "EndTime": 1596998343.667596, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.667578}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 8.302821605668768e-06, "sum": 8.302821605668768e-06, "min": 8.302821605668768e-06}}, "EndTime": 1596998343.667651, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.66764}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0018544386495714601, "sum": 0.0018544386495714601, "min": 0.0018544386495714601}}, "EndTime": 1596998343.667693, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.667682}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0007810008784999018, "sum": 0.0007810008784999018, "min": 0.0007810008784999018}}, "EndTime": 1596998343.667759, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.667742}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0018555038299249565, "sum": 0.0018555038299249565, "min": 0.0018555038299249565}}, "EndTime": 1596998343.667817, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.667806}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.000780865002585494, "sum": 0.000780865002585494, "min": 0.000780865002585494}}, "EndTime": 1596998343.667869, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.667854}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 1.5828009168414967e-05, "sum": 1.5828009168414967e-05, "min": 1.5828009168414967e-05}}, "EndTime": 1596998343.66794, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.667921}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 8.457714595588978e-06, "sum": 8.457714595588978e-06, "min": 8.457714595588978e-06}}, "EndTime": 1596998343.668007, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.667995}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 1.574870810398589e-05, "sum": 1.574870810398589e-05, "min": 1.574870810398589e-05}}, "EndTime": 1596998343.668077, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.668059}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 8.465043436128485e-06, "sum": 8.465043436128485e-06, "min": 8.465043436128485e-06}}, "EndTime": 1596998343.668143, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998343.668126}
#
# [08/09/2020 18:39:03 INFO 139978268763968] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.00185446806187
# [08/09/2020 18:39:03 INFO 139978268763968] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=8.1579655753e-06
# [08/09/2020 18:39:03 INFO 139978268763968] Epoch 14: Loss improved. Updating best model
# [08/09/2020 18:39:03 INFO 139978268763968] Saving model for epoch: 14
# [08/09/2020 18:39:03 INFO 139978268763968] Saved checkpoint to "/tmp/tmpAgw0LT/mx-mod-0000.params"
# [08/09/2020 18:39:03 INFO 139978268763968] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 116, "sum": 116.0, "min": 116}, "Number of Batches Since Last Reset": {"count": 1, "max": 116, "sum": 116.0, "min": 116}, "Number of Records Since Last Reset": {"count": 1, "max": 23158, "sum": 23158.0, "min": 23158}, "Total Batches Seen": {"count": 1, "max": 1792, "sum": 1792.0, "min": 1792}, "Total Records Seen": {"count": 1, "max": 357770, "sum": 357770.0, "min": 357770}, "Max Records Seen Between Resets": {"count": 1, "max": 23158, "sum": 23158.0, "min": 23158}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1596998343.675643, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1596998340.314373}
#
# [08/09/2020 18:39:03 INFO 139978268763968] #throughput_metric: host=algo-1, train throughput=6889.42624711 records/second
# [08/09/2020 18:39:03 WARNING 139978268763968] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [08/09/2020 18:39:03 WARNING 139978268763968] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-08-09 18:39:03.677] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 1, "num_examples": 1, "num_bytes": 16800}
# [2020-08-09 18:39:03.958] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 278, "num_examples": 116, "num_bytes": 1945272}
# [2020-08-09 18:39:04.300] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 327, "num_examples": 116, "num_bytes": 1945272}
# [08/09/2020 18:39:04 ERROR 139978268763968] Algorithm Error: Only one class present in y_true. ROC AUC score is not defined in that case. (caused by ValueError)
#
# Caused by: Only one class present in y_true. ROC AUC score is not defined in that case.
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# <ipython-input-30-63857941d376> in <module>
#      18                            mini_batch_size=200)
#      19
# ---> 20 linear.fit({'train': s3_train_data})
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     497         self.jobs.append(self.latest_training_job)
#     498         if wait:
# --> 499             self.latest_training_job.wait(logs=logs)
#     500
#     501     def _compilation_job_name(self):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/estimator.py in wait(self, logs)
#    1114         # If logs are requested, call logs_for_jobs.
#    1115         if logs != "None":
# -> 1116             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    1117         else:
#    1118             self.sagemaker_session.wait_for_job(self.job_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3075
#    3076         if wait:
# -> 3077             self._check_job_status(job_name, description, "TrainingJobStatus")
#    3078             if dot:
#    3079                 print()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#    2669                 ),
#    2670                 allowed_statuses=["Completed", "Stopped"],
# -> 2671                 actual_status=status,
#    2672             )
#    2673
#
# UnexpectedStatusException: Error for Training job linear-learner-2020-08-09-18-34-41-763: Failed. Reason: InternalServerError: We encountered an internal error. Please try again.
