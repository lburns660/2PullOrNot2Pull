# %%
covid_df = pd.read_csv('../datasets/COVID-19_patient_pre-condition_dataset/covid.csv', index_col='id')
covid_df.head()
# Out:
#         sex  patient_type  entry_date date_symptoms   date_died  intubed  \
# id
# 16169f    2             1  04-05-2020    02-05-2020  9999-99-99       97
# 1009bf    2             1  19-03-2020    17-03-2020  9999-99-99       97
# 167386    1             2  06-04-2020    01-04-2020  9999-99-99        2
# 0b5948    2             2  17-04-2020    10-04-2020  9999-99-99        2
# 0d01b5    1             2  13-04-2020    13-04-2020  22-04-2020        2
#
#         pneumonia  age  pregnancy  diabetes  ...  inmsupr  hypertension  \
# id                                           ...
# 16169f          2   27         97         2  ...        2             2
# 1009bf          2   24         97         2  ...        2             2
# 167386          2   54          2         2  ...        2             2
# 0b5948          1   30         97         2  ...        2             2
# 0d01b5          2   60          2         1  ...        2             1
#
# ...

# %%
len(covid_df)
# Out:
# 566602

# %%
# Drop any rows that are nan see what we're left with

# %%
covid_df.columns
# Out:
# Index(['sex', 'patient_type', 'entry_date', 'date_symptoms', 'date_died',
#        'intubed', 'pneumonia', 'age', 'pregnancy', 'diabetes', 'copd',
#        'asthma', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular',
#        'obesity', 'renal_chronic', 'tobacco', 'contact_other_covid',
#        'covid_res', 'icu'],
#       dtype='object')

# %%
covid_df_small=covid_df.copy()
columns_to_drop_above_97=[
       'intubed', 'pneumonia', 'pregnancy', 'diabetes', 'copd',
       'asthma', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular',
       'obesity', 'renal_chronic', 'tobacco', 'contact_other_covid',
       'covid_res', 'icu']
# columns_to_drop_above_97=[
#        'intubed', 'pneumonia', '']
for col in columns_to_drop_above_97:
    covid_df_small = covid_df_small[covid_df_small[col]<97]





covid_df_small
# Out:
#         sex  patient_type  entry_date date_symptoms   date_died  intubed  \
# id
# 154fea    1             2  02-06-2020    02-06-2020  9999-99-99        2
# 16e14e    1             2  22-06-2020    17-06-2020  9999-99-99        2
# 149f1c    1             2  17-06-2020    12-06-2020  9999-99-99        2
# 1d5df2    1             2  08-06-2020    07-06-2020  9999-99-99        1
# 18f860    1             2  27-05-2020    27-05-2020  9999-99-99        2
# ...     ...           ...         ...           ...         ...      ...
# 70426     1             2  19-06-2020    12-06-2020  9999-99-99        2
# 0143db    1             2  24-06-2020    21-06-2020  9999-99-99        2
# 188cd4    1             2  06-06-2020    01-06-2020  9999-99-99        2
# 1d5382    1             2  21-06-2020    16-06-2020  9999-99-99        2
# 028be6    1             2  05-06-2020    23-05-2020  14-06-2020        1
#
#         pneumonia  age  pregnancy  diabetes  ...  inmsupr  hypertension  \
# ...

# %%
# did they die tho 
covid_df['Died?'] = covid_df['date_died'].apply(lambda x: 1 if x == '9999-99-99' else 2)

# %%
known_intubed = covid_df_small[covid_df_small.intubed < 97]

# %%
# What percentage of intubed is true
for index, row in covid_df_small.iterrows():
#     print(row.intubed)
# Out:
#   File "<ipython-input-12-f2afe23b5778>", line 4
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
covid_df_small=covid_df.copy()
covid_df_small["intubed"]=covid_df_small["intubed"].apply(lambda x:"" if x>2 else x)
len(covid_df_small.dropna())
# Out:
# 566602

# %%
covid_df[0:10]
# Out:
#           sex  patient_type  entry_date date_symptoms   date_died  intubed  \
# id
# 16169f      2             1  04-05-2020    02-05-2020  9999-99-99       97
# 1009bf      2             1  19-03-2020    17-03-2020  9999-99-99       97
# 167386      1             2  06-04-2020    01-04-2020  9999-99-99        2
# 0b5948      2             2  17-04-2020    10-04-2020  9999-99-99        2
# 0d01b5      1             2  13-04-2020    13-04-2020  22-04-2020        2
# 1beec8      2             2  16-04-2020    16-04-2020  29-04-2020        2
# 1.75E+56    2             2  22-04-2020    13-04-2020  9999-99-99        2
# 0ce1f5      1             1  21-05-2020    18-05-2020  9999-99-99       97
# 12b57a      1             1  22-04-2020    18-04-2020  9999-99-99       97
# 006b91      1             2  23-04-2020    18-04-2020  9999-99-99        1
#
#           pneumonia  age  pregnancy  diabetes  ...  hypertension  \
# id                                             ...
# ...

# %%
from sklearn import svm

# %%
# Make array from 
# columns_to_train=[ 'pneumonia', 'pregnancy', 'diabetes', 'copd',
#        'asthma', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular',
#        'obesity']
# column_class=["intubed"]
columns_to_train=[ 'pneumonia', 'diabetes', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular',
       'obesity','sex', 'age',]
column_class=["intubed"]

# %%
x=covid_df[columns_to_train].to_numpy()
y=covid_df["intubed"].to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=45)

# %%
knn_classifier = KNeighborsClassifier(n_neighbors=3)
knn_classifier.fit(X_train, y_train) 


# predict the response
knn_prediction = knn_classifier.predict(X_test)

# %%
print(accuracy_score(y_test, knn_prediction))
# Out:
# 0.8482538068915857

# %%
# Logistic regression

# Create logistic regression object
# Try different solvers:  'newton-cg', 'sag', 'saga' and 'lbfgs'
logistic_regression_classifier = linear_model.LogisticRegression(random_state=0, solver='lbfgs',multi_class='multinomial')

# Train the model using the training sets
logistic_regression_classifier.fit(X_train,y_train)

# Make predictions using the testing set
logistic_regression_classifier_prediction = logistic_regression_classifier.predict(X_test)


# evaluate accuracy
print(accuracy_score(y_test, logistic_regression_classifier_prediction))
# Out:
# 0.8698067786319899
# /Users/laurenb/Documents/ML/BuildingFirstSciKitLearnSolution/env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:938: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# identify the correlation between every feature
covid_corr = covid_df.corr()
fig, ax = plt.subplots(figsize=(15,15)) 
sns.heatmap(covid_corr, annot=True, linewidths=1, ax=ax)

# %%
covid_corr = covid_without_icu_preg_patienttype_subset_df.corr()
fig, ax = plt.subplots(figsize=(15,15)) 
sns.heatmap(covid_corr, annot=True, linewidths=1, ax=ax)

# %%
covid_corr = covid_without_icu_preg_patienttype_conditions_subset_df.corr()
fig, ax = plt.subplots(figsize=(15,15)) 
sns.heatmap(covid_corr, annot=True, linewidths=1, ax=ax)

# %%
covid_without_icu_preg_patienttype_subset_df = covid_df.copy()

# %%
covid_without_icu_preg_patienttype_subset_df = covid_without_icu_preg_patienttype_subset_df.drop(columns=['icu', 'pregnancy', 'patient_type'])

# %%
covid_without_icu_preg_patienttype_conditions_subset_df = covid_without_icu_preg_patienttype_subset_df.copy()
covid_without_icu_preg_patienttype_conditions_subset_df = covid_without_icu_preg_patienttype_conditions_subset_df.drop(columns=['copd', 'cardiovascular'])

# %%
list(covid_without_icu_preg_patienttype_conditions_subset_df.columns.values)
# Out:
# ['sex',
#  'entry_date',
#  'date_symptoms',
#  'date_died',
#  'intubed',
#  'pneumonia',
#  'age',
#  'diabetes',
#  'asthma',
#  'inmsupr',
#  'hypertension',
#  'other_disease',
#  'obesity',
#  'renal_chronic',
#  'tobacco',
#  'contact_other_covid',
#  'covid_res',
#  'Died?']

# %%
# investigartnig the correlation between pregnant women, non pregnant women and likelihood of intubation 
covid_female_pregnant = covid_df[(covid_df.sex == 1) & (covid_df.pregnancy == 1)]

# %%
list(covid_female_pregnant.columns.values)
# Out:
# ['sex',
#  'patient_type',
#  'entry_date',
#  'date_symptoms',
#  'date_died',
#  'intubed',
#  'pneumonia',
#  'age',
#  'pregnancy',
#  'diabetes',
#  'copd',
#  'asthma',
#  'inmsupr',
#  'hypertension',
#  'other_disease',
#  'cardiovascular',
#  'obesity',
#  'renal_chronic',
#  'tobacco',
#  'contact_other_covid',
#  'covid_res',
#  'icu',
#  'Died?']

# %%
covid_female_nonpregnant = covid_df[(covid_df.sex == 1) & (covid_df.pregnancy == 2)]

# %%
covid_female_nonpregnant.count()
# Out:
# sex                    273840
# patient_type           273840
# entry_date             273840
# date_symptoms          273840
# date_died              273840
# intubed                273840
# pneumonia              273840
# age                    273840
# pregnancy              273840
# diabetes               273840
# copd                   273840
# asthma                 273840
# inmsupr                273840
# hypertension           273840
# other_disease          273840
# cardiovascular         273840
# obesity                273840
# renal_chronic          273840
# tobacco                273840
# contact_other_covid    273840
# covid_res              273840
# icu                    273840
# Died?                  273840
# dtype: int64

# %%
covid_df[(covid_df.sex == 1)].count()
# Out:
# sex                    279490
# patient_type           279490
# entry_date             279490
# date_symptoms          279490
# date_died              279490
# intubed                279490
# pneumonia              279490
# age                    279490
# pregnancy              279490
# diabetes               279490
# copd                   279490
# asthma                 279490
# inmsupr                279490
# hypertension           279490
# other_disease          279490
# cardiovascular         279490
# obesity                279490
# renal_chronic          279490
# tobacco                279490
# contact_other_covid    279490
# covid_res              279490
# icu                    279490
# Died?                  279490
# dtype: int64

# %%
covid_female_nonpregnant[(covid_female_nonpregnant.intubed == 1)].count()
# Out:
# sex                    3376
# patient_type           3376
# entry_date             3376
# date_symptoms          3376
# date_died              3376
# intubed                3376
# pneumonia              3376
# age                    3376
# pregnancy              3376
# diabetes               3376
# copd                   3376
# asthma                 3376
# inmsupr                3376
# hypertension           3376
# other_disease          3376
# cardiovascular         3376
# obesity                3376
# renal_chronic          3376
# tobacco                3376
# contact_other_covid    3376
# covid_res              3376
# icu                    3376
# Died?                  3376
# dtype: int64
